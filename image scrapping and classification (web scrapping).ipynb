# %%
#importing all the required libraries
import selenium
import pandas as pd
from selenium import webdriver # Importing selenium webdriver
import time

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
#creating empty lists
Sarees_Image=[]
Trousers_Image=[]
Jeans_Image=[]

# %%
#search_list=['sarees','trousers','jeans']

# %%
url1='https://www.amazon.in/'

# %%
driver_1 = webdriver.Chrome(r"C:\Users\lenovo\Downloads\chromedriver_win32 (8)\chromedriver.exe") 
driver_1.get(url1)

# searching required fields
search_bar = driver_1.find_element_by_id("twotabsearchtextbox")    # Locating searc_bar by id                                              # clearing search_bar
search_bar.send_keys('sarees')

search_button = driver_1.find_element_by_xpath('//span[@id="nav-search-submit-text"]/input')       # Locating search_button by xpath
search_button.click()


start_page = 0
end_page = 5
for i in range(start_page,end_page+1):
    sar=driver_1.find_elements_by_xpath("//div[@class='a-section aok-relative s-image-tall-aspect']/img")
    for j in sar:
        image=j.get_attribute('src')
        Sarees_Image.append(image)
# Out:
# <ipython-input-14-41edefff77b2>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver_1 = webdriver.Chrome(r"C:\Users\lenovo\Downloads\chromedriver_win32 (8)\chromedriver.exe")
# <ipython-input-14-41edefff77b2>:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_bar = driver_1.find_element_by_id("twotabsearchtextbox")    # Locating searc_bar by id                                              # clearing search_bar
# <ipython-input-14-41edefff77b2>:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_button = driver_1.find_element_by_xpath('//span[@id="nav-search-submit-text"]/input')       # Locating search_button by xpath
# <ipython-input-14-41edefff77b2>:15: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# ...

# %%
Sarees_Image
# Out:
# ['https://m.media-amazon.com/images/I/415njKMWKcL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81dS+-qqTyL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81E3SVH-WTL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/91TfjndvOWL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81aaDUrREUS._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/91Utl0DCCBL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/91zuOcKe0YL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/619cbp-6mAL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/91NhFxRQe7L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81j-y-KWb6L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/913Ch5MZ0aL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71SUNh9g6bL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/91ecd4QxIdS._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/91UN3kCM5HL._AC_UL320_.jpg',
# ...

# %%
len(Sarees_Image)
# Out:
# 678

# %%
driver_1 = webdriver.Chrome(r"C:\Users\lenovo\Downloads\chromedriver_win32 (8)\chromedriver.exe")
driver_1.get(url1)

# searching required fields
search_bar = driver_1.find_element_by_id("twotabsearchtextbox")    # Locating searc_bar by id                                              # clearing search_bar
search_bar.send_keys('trousers for men')

search_button = driver_1.find_element_by_xpath('//span[@id="nav-search-submit-text"]/input')       # Locating search_button by xpath
search_button.click()


start_page = 0
end_page = 5
for i in range(start_page,end_page+1):
    sar=driver_1.find_elements_by_xpath("//div[@class='a-section aok-relative s-image-tall-aspect']/img")
    for j in sar:
        image=j.get_attribute('src')
        Trousers_Image.append(image)
# Out:
# <ipython-input-17-3a71a7ed59f0>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver_1 = webdriver.Chrome(r"C:\Users\lenovo\Downloads\chromedriver_win32 (8)\chromedriver.exe")
# <ipython-input-17-3a71a7ed59f0>:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_bar = driver_1.find_element_by_id("twotabsearchtextbox")    # Locating searc_bar by id                                              # clearing search_bar
# <ipython-input-17-3a71a7ed59f0>:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_button = driver_1.find_element_by_xpath('//span[@id="nav-search-submit-text"]/input')       # Locating search_button by xpath
# <ipython-input-17-3a71a7ed59f0>:15: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# ...

# %%
Trousers_Image
# Out:
# ['https://m.media-amazon.com/images/I/71dq1l3u+9L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/51GPPdnaZCL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81V+cLWewjL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71lbPM5z1eL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/61nLJ+MDbWL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/514V07E7sOL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/5176NcNty0L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/61NKxXc+lIL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71Nv4QblWfL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81PFSJgM4kL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71lH6YbxvkL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71kU8iG29oL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81d37fLAwUL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/61KwCbPkOyL._AC_UL320_.jpg',
# ...

# %%
len(Trousers_Image)
# Out:
# 432

# %%
driver_1 = webdriver.Chrome(r"C:\Users\lenovo\Downloads\chromedriver_win32 (8)\chromedriver.exe")
driver_1.get(url1)

# searching required fields
search_bar = driver_1.find_element_by_id("twotabsearchtextbox")    # Locating searc_bar by id                                              # clearing search_bar
search_bar.send_keys('jeans for men')

search_button = driver_1.find_element_by_xpath('//span[@id="nav-search-submit-text"]/input')       # Locating search_button by xpath
search_button.click()


start_page = 0
end_page = 5
for i in range(start_page,end_page+1):
    sar=driver_1.find_elements_by_xpath("//div[@class='a-section aok-relative s-image-tall-aspect']/img")
    for j in sar:
        image=j.get_attribute('src')
        Jeans_Image.append(image)
# Out:
# <ipython-input-20-79c5b84b28a3>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver_1 = webdriver.Chrome(r"C:\Users\lenovo\Downloads\chromedriver_win32 (8)\chromedriver.exe")
# <ipython-input-20-79c5b84b28a3>:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_bar = driver_1.find_element_by_id("twotabsearchtextbox")    # Locating searc_bar by id                                              # clearing search_bar
# <ipython-input-20-79c5b84b28a3>:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_button = driver_1.find_element_by_xpath('//span[@id="nav-search-submit-text"]/input')       # Locating search_button by xpath
# <ipython-input-20-79c5b84b28a3>:15: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# ...

# %%
Jeans_Image
# Out:
# ['https://m.media-amazon.com/images/I/616xchp1ECL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/61+nyy9oqDL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/517MMoc6lbS._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/617SAeg8hPL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/616xchp1ECL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81I3n9hexWL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81d44SH+12L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81rcMJm4kFL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81K6Ry1DC5L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71iKWIHWoQL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81BScnSqJtL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/91d-bL+0EeL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81LV0z3JD+L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/810mz0xP8BL._AC_UL320_.jpg',
# ...

# %%
len(Jeans_Image)
# Out:
# 450

# %%
Sarees=[]
Sarees=Sarees_Image[0:200]
len(Sarees)
# Out:
# 200

# %%
Trousers=[]
Trousers=Trousers_Image[0:200]
len(Trousers)
# Out:
# 200

# %%
Jeans=[]
Jeans=Jeans_Image[0:200]
len(Jeans)
# Out:
# 200

# %%
# Creating Directories
import os

def directory(dir):
    current_path=os.getcwd()
    new=os.path.join(current_path,dir)
    if not os.path.exists(new):
        os.makedirs(new)
        
directory('Sarees_Images')
directory('Trousers_Images')
directory('Jeans_Images')

# Dowloading images

import shutil
import requests

# %%
for index, link in enumerate(Sarees):
    print('Downloading {0} of 200 saree images'.format(index+1))
    response=requests.get(link)
    with open('Sarees_Images/img{0}.jpeg'.format(index+1),"wb") as file:
        file.write(response.content)

# %%
for index, link in enumerate(Trousers):
    print('Downloading {0} of 200 trouser images'.format(index+1))
    response=requests.get(link)
    with open('Trousers_Images/img{0}.jpeg'.format(index+1),"wb") as file:
        file.write(response.content)

# %%
for index, link in enumerate(Jeans):
    print('Downloading {0} of 200 jeans images'.format(index+1))
    response=requests.get(link)
    with open('Jeans_Images/img{0}.jpeg'.format(index+1),"wb") as file:
        file.write(response.content)
